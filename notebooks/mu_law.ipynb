# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  librosa as lr

# %% [markdown]
# ## data

# %%
data, sr=lr.load(path='data/rich001.wav', sr=16000)

# %% [markdown]
# ## Helpers

# %%
def mu_law_encoding(data, mu):
    mu_x = np.sign(data) * np.log(1 + mu * np.abs(data)) / np.log(mu + 1)
    return mu_x

# %%
def mu_law_expansion(data, mu):
    s = np.sign(data) * (np.exp(np.abs(data) * np.log(mu + 1)) - 1) / mu
    return s

# %% [markdown]
# Some reading http://digitalsoundandmusic.com/5-3-8-algorithms-for-audio-companding-and-compression/

# %% [markdown]
# ## Example

# %%
classes=256

# %%
encoded_data=mu_law_encoding(data, classes)

# %%
plt.plot(data)

# %%
len(set(data)), min(data), max(data)
# Out:
# (4984, -0.83148193, 0.8850403)

# %%
plt.plot(encoded_data)

# %%
len(set(encoded_data)), min(encoded_data), max(encoded_data)
# Out:
# (4984, -0.9668851, 0.97808343)

# %%
plt.scatter(data, encoded_data)

# %%
data_back=mu_law_expansion(encoded_data, classes)

# %%
plt.plot(data_back)

# %%
plt.scatter(data, data_back)
